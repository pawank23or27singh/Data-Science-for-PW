# %%
import numpy as np
import pandas as pd
lst_marks=[45,32,56,89,33,45,67,87,54,89,98,76,1000,1100]

# %%
# lower face and higher frace
Q1=np.percentile(lst_marks,[25])
print(Q1)
# Out:
# [47.25]

# %%
minimum,Q1,Q2,Q3,maximum=np.quantile(lst_marks,[0,0.25,0.50,0.75,1.0])

# %%
maximum
# Out:
# np.float64(1100.0)

# %%
IQR=Q3-Q1
print(IQR)
# Out:
# 41.75

# %%
lower_fence=Q1-1.5*(IQR)
higher_fence=Q3+1.5*(IQR)

# %%
lower_fence
# higher_fence
# Out:
# np.float64(-15.375)

# %%
higher_fence
# Out:
# np.float64(151.625)

# %%
outliers=[]

for i in lst_marks:
    if i>=-15.375 and i<=151.625:
        print("This element is not in outlier")
    else:
        outliers.append(i)
# Out:
# This element is not in outlier
# This element is not in outlier
# This element is not in outlier
# This element is not in outlier
# This element is not in outlier
# This element is not in outlier
# This element is not in outlier
# This element is not in outlier
# This element is not in outlier
# This element is not in outlier
# This element is not in outlier
# This element is not in outlier

# %%
outliers
# Out:
# [1000, 1100]

# %%
import seaborn as sns
sns.boxplot(lst_marks)
# Out:
# <Axes: >

# %%
lst_marks=[45,32,56,89,33,45,67,87,54,89,98,76,1000,1100]
sns.boxplot(lst_marks)
# Out:
# <Axes: >
